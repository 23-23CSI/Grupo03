# %%
#Lorem ipsum
# !pip install lorem-text
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: lorem-text in /usr/local/lib/python3.10/dist-packages (2.1)
# Requirement already satisfied: Click>=7.0 in /usr/local/lib/python3.10/dist-packages (from lorem-text) (8.1.3)

# %%
# HKDF
from cryptography.hazmat.primitives.asymmetric import ec
from cryptography.hazmat.primitives import serialization
from cryptography.hazmat.backends import default_backend
from cryptography.hazmat.primitives import hashes
from cryptography.hazmat.primitives.kdf.hkdf import HKDF
from cryptography.hazmat.primitives.ciphers import Cipher, algorithms, modes
import os

# %%
import time

# %%
from lorem_text import lorem

def generar_lorem(num_palabras):
    texto = lorem.words(num_palabras)
    return texto

# %% [markdown]
# ##1. Leer un archivo con el texto del mensaje a cifrar.

# %%
numPalabras = int(input("Ingrese el numero de palabras a encriptar:"))
# Out:
# Ingrese el numero de palabras a encriptar:1000000

# %%
inicio = time.time()

mensaje = generar_lorem(numPalabras).encode()

fin = time.time()

duracion = fin - inicio

print("Tiempo de ejecución:", duracion*1000, "milisegundos")
# Out:
# Tiempo de ejecución: 461.32969856262207 milisegundos

# %% [markdown]
# ##2. Generar e imprimir la(las) claves de cifrado y/o descifrado.

# %%
inicio = time.time()

private_key1 = ec.generate_private_key(ec.SECP256R1(), default_backend())
public_key1 = private_key1.public_key()

private_key2 = ec.generate_private_key(ec.SECP256R1(), default_backend())
public_key2 = private_key2.public_key()

shared_key1 = private_key1.exchange(ec.ECDH(), public_key2)
shared_key2 = private_key2.exchange(ec.ECDH(), public_key1)

print('Clave privada 1:',private_key1)
print('Clave publica 1:',public_key1)
print('Clave privada 2:',private_key2)
print('Clave publica 2:',public_key2)

print('Clave compartida 1:',shared_key1)
print('Clave compartida 2:',shared_key2)

fin = time.time()

duracion = fin - inicio

print("Tiempo de ejecución:", duracion*1000, "milisegundos")
# Out:
# Clave privada 1: <cryptography.hazmat.backends.openssl.ec._EllipticCurvePrivateKey object at 0x7fcfedb815a0>
# Clave publica 1: <cryptography.hazmat.backends.openssl.ec._EllipticCurvePublicKey object at 0x7fcfedb816c0>
# Clave privada 2: <cryptography.hazmat.backends.openssl.ec._EllipticCurvePrivateKey object at 0x7fcfedb81540>
# Clave publica 2: <cryptography.hazmat.backends.openssl.ec._EllipticCurvePublicKey object at 0x7fcfedb83a30>
# Clave compartida 1: b'5\xda\xcc\x01\xbb\xe7\x9d\xa9DtKfe\xe8(F\xa4\xa6\x14\x81\x13\xa1\xae/]\xa2\x89\x7f\xd5\x9e|M'
# Clave compartida 2: b'5\xda\xcc\x01\xbb\xe7\x9d\xa9DtKfe\xe8(F\xa4\xa6\x14\x81\x13\xa1\xae/]\xa2\x89\x7f\xd5\x9e|M'
# Tiempo de ejecución: 10.068416595458984 milisegundos

# %% [markdown]
# ##3. Cifrar e imprimir el texto.

# %%
inicio = time.time()

hkdf = HKDF(
    algorithm=hashes.SHA256(),
    length=32,
    salt=None,
    info=b'session_key',
    backend=default_backend()
)
session_key = hkdf.derive(shared_key1)

nonce = os.urandom(16)
cipher = Cipher(algorithms.AES(session_key), modes.CTR(nonce), backend=default_backend())
encryptor = cipher.encryptor()
ciphertext = encryptor.update(mensaje) + encryptor.finalize()


#print('Texto cifrado:',ciphertext.hex())

texto_cifrado=ciphertext.hex()

archi1=open("datosCifrado.txt","w")
archi1.write(texto_cifrado)
archi1.close()


fin = time.time()

duracion = fin - inicio

print("Tiempo de ejecución:", duracion*1000, "milisegundos")
# Out:
# Tiempo de ejecución: 59.77940559387207 milisegundos

# %% [markdown]
# ##4. Descifrar e imprimir el texto.

# %%
inicio = time.time()

decryptor = cipher.decryptor()
decrypted_text = decryptor.update(ciphertext) + decryptor.finalize()

if decrypted_text == mensaje:
  print("Descifrado correcto")

#print('Texto descifrado:',decrypted_text.decode())


texto_decifrado=decrypted_text.decode()

archi1=open("datosDecifrado.txt","w")
archi1.write(texto_decifrado)
archi1.close()

fin = time.time()

duracion = fin - inicio
print("Tiempo de ejecución:", duracion*1000, "milisegundos")
# Out:
# Descifrado correcto
# Tiempo de ejecución: 32.25111961364746 milisegundos
